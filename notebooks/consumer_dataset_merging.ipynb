# %% [markdown]
# # Consumer's dataset merging process

# %%
import folium
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_parquet("../data/curated/consumer/")
processed_postcode = pd.read_csv('../data/curated/processed_postcode.csv')
processed_postcode = processed_postcode[['postcode', 'SA2_code']]
processed_postcode
# Out:
#       postcode     SA2_code
# 0          200  801051049.0
# 1          800  701011002.0
# 2          801  701011002.0
# 3          804  701011009.0
# 4          810  701021010.0
# ...        ...          ...
# 3162      9013  310031284.0
# 3163      9015  310031284.0
# 3164      9464  302031038.0
# 3165      9726  309101268.0
# 3166      9999  206041505.0
#
# [3167 rows x 2 columns]

# %%
# ACT has multiple areas with postcode 2611, check the existance
df.loc[(df['postcode']==2611) & (df['state'] == 'ACT')]
# Out:
# Empty DataFrame
# Columns: [consumer_id, user_id, name, address, state, postcode, gender]
# Index: []

# %%
df = df.merge(processed_postcode, on='postcode', how='left')
df
# Out:
#         consumer_id  user_id              name  \
# 0                28   458885   Gregory Barrett
# 1                78   319257         Cory Best
# 2               101     9180   Jasmine Sanchez
# 3               108   191536    Karen Robinson
# 4               133   234634  Christopher Cook
# ...             ...      ...               ...
# 499994      1499570   400937     Terry Johnson
# 499995      1499611   206860         Lisa King
# 499996      1499869   381121   Elizabeth Moore
# 499997      1499911    56561      Rhonda Berry
# 499998      1499917   360988    Jason Richmond
#
#                                address state  postcode  gender     SA2_code
# 0                     7083 Carson Lane    WA      6176    Male  507051314.0
# 1                   992 Becky Junction    SA      5410    Male  405011111.0
# 2        598 Johnson Motorway Apt. 104    SA      5554  Female  405041124.0
# 3           638 Chen Islands Suite 258    SA      5052  Female  403031065.0
# 4              701 Diaz Walks Apt. 086    WA      6985    Male  501021007.0
# ...                                ...   ...       ...     ...          ...
# 499994                 884 Nicole Pine   VIC      3579  Female  215031401.0
# 499995             95327 Walter Island    SA      5134  Female  401021010.0
# 499996  21645 Jackson Landing Apt. 066   QLD      4403  Female  307021180.0
# 499997      02494 Day Islands Apt. 198    WA      6105  Female  506021121.0
# 499998    404 Martinez Light Suite 434   NSW      2292    Male  111031224.0
#
# [499999 rows x 8 columns]

# %%
#TODO: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl

income_df = pd.read_excel('../data/external/total_income.xlsx', sheet_name='Table 1.4')
income_df
# Out:
#                         Australian Bureau of Statistics  \
# 0     Personal Income in Australia Table 1. Total In...
# 1       Released at 11:30 am (Canberra time) 22/01/2021
# 2                                             Table 1.4
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2301                                          801111140
# 2302                                          801111141
# 2303                                                NaN
# 2304  Totals may not align with the sum of their com...
# 2305  np - not published to protect the confidential...
#
#                                              Unnamed: 1         Unnamed: 2  \
# 0                                                   NaN                NaN
# 1                                                   NaN                NaN
# 2     Total Income by Statistical Area Level 2 (2014...                NaN
# 3                                                   NaN                NaN
# 4                                                   NaN  Earners (persons)
# ...                                                 ...                ...
# 2301                                   ACT - South West                349
# 2302                                            Namadgi                 np
# 2303                                                NaN                NaN
# 2304                                                NaN                NaN
# 2305                                                NaN                NaN
#
#      Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0           NaN        NaN        NaN        NaN
# 1           NaN        NaN        NaN        NaN
# 2           NaN        NaN        NaN        NaN
# 3           NaN        NaN        NaN        NaN
# 4           NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...
# 2301        289        347        364        355
# 2302         np         21         19         18
# 2303        NaN        NaN        NaN        NaN
# 2304        NaN        NaN        NaN        NaN
# 2305        NaN        NaN        NaN        NaN
#
#                          Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 18  \
# 0                               NaN        NaN        NaN  ...         NaN
# 1                               NaN        NaN        NaN  ...         NaN
# 2                               NaN        NaN        NaN  ...         NaN
# 3                               NaN        NaN        NaN  ...         NaN
# 4     Median age of earners (years)        NaN        NaN  ...         NaN
# ...                             ...        ...        ...  ...         ...
# 2301                             40         39         39  ...       62592
# 2302                             np         np         34  ...          np
# 2303                            NaN        NaN        NaN  ...         NaN
# 2304                            NaN        NaN        NaN  ...         NaN
# 2305                            NaN        NaN        NaN  ...         NaN
#
#      Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN    Mean ($)         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 2301       55384       61096       64227       62505       72858       70503
# 2302       49981       58498       40479          np          np       57309
# 2303         NaN         NaN         NaN         NaN         NaN         NaN
# 2304         NaN         NaN         NaN         NaN         NaN         NaN
# 2305         NaN         NaN         NaN         NaN         NaN         NaN
#
#      Unnamed: 25 Unnamed: 26 Unnamed: 27
# 0            NaN         NaN         NaN
# 1            NaN         NaN         NaN
# 2            NaN         NaN         NaN
# 3            NaN         NaN         NaN
# 4            NaN         NaN         NaN
# ...          ...         ...         ...
# 2301       67445       73435         NaN
# 2302       56357       39278         NaN
# 2303         NaN         NaN         NaN
# 2304         NaN         NaN         NaN
# 2305         NaN         NaN         NaN
#
# [2306 rows x 28 columns]

# %%
income_df1 = income_df.drop(income_df.index[0:6], inplace=False).reset_index(drop=True)
income_df1.columns = income_df.iloc[5].values.flatten().tolist()
income_df1 = (income_df1.iloc[:, [0, 1, 26]])
income_df1.drop(income_df1.index[2297:2300], inplace=True)
income_df1.rename(columns={'2018-19':'Mean Total Income'}, inplace=True)
income_df1.rename(columns={'SA2':'SA2_code'}, inplace=True)
#income_df1['Mean Total Income'].replace('np', np.NAN)
income_df1 = income_df1.dropna().reset_index()
#income_df1.astype({'SA2': 'int'})
income_df1
# Out:
#       index   SA2_code           SA2 NAME Mean Total Income
# 0         2  101021007          Braidwood             51149
# 1         3  101021008            Karabar             66335
# 2         4  101021009         Queanbeyan             65874
# 3         5  101021010  Queanbeyan - East             69860
# 4         6  101021011  Queanbeyan Region             81919
# ...     ...        ...                ...               ...
# 2283   2292  801101137           Molonglo                np
# 2284   2293  801101138   Molonglo - North                np
# 2285   2294  801101139             Wright             86007
# 2286   2295  801111140   ACT - South West             73435
# 2287   2296  801111141            Namadgi             39278
#
# [2288 rows x 4 columns]

# %%
(income_df1['Mean Total Income'] == 'np').sum()
# Out:
# 44

# %%
# missing value checking for mean total income
SA2_missing = (income_df1['SA2 NAME'].where(income_df1['Mean Total Income'] == 'np')).dropna()
SA2_missing.size
# Out:
# 44

# %%
# combining consumer with mean total income based on SA2 code
df = df.merge(income_df1, on='SA2_code', how='left')
df
# Out:
#         consumer_id  user_id              name  \
# 0                28   458885   Gregory Barrett
# 1                78   319257         Cory Best
# 2               101     9180   Jasmine Sanchez
# 3               108   191536    Karen Robinson
# 4               133   234634  Christopher Cook
# ...             ...      ...               ...
# 499994      1499570   400937     Terry Johnson
# 499995      1499611   206860         Lisa King
# 499996      1499869   381121   Elizabeth Moore
# 499997      1499911    56561      Rhonda Berry
# 499998      1499917   360988    Jason Richmond
#
#                                address state  postcode  gender     SA2_code  \
# 0                     7083 Carson Lane    WA      6176    Male  507051314.0
# 1                   992 Becky Junction    SA      5410    Male  405011111.0
# 2        598 Johnson Motorway Apt. 104    SA      5554  Female  405041124.0
# 3           638 Chen Islands Suite 258    SA      5052  Female  403031065.0
# 4              701 Diaz Walks Apt. 086    WA      6985    Male  501021007.0
# ...                                ...   ...       ...     ...          ...
# 499994                 884 Nicole Pine   VIC      3579  Female  215031401.0
# 499995             95327 Walter Island    SA      5134  Female  401021010.0
# 499996  21645 Jackson Landing Apt. 066   QLD      4403  Female  307021180.0
# 499997      02494 Day Islands Apt. 198    WA      6105  Female  506021121.0
# 499998    404 Martinez Light Suite 434   NSW      2292    Male  111031224.0
#
#          index                SA2 NAME Mean Total Income
# 0          NaN                     NaN               NaN
# 1       1682.0                   Light             55650
# 2       1695.0                  Kadina             51413
# 3       1636.0                  Belair             73814
# 4       1749.0                   Capel             60552
# ...        ...                     ...               ...
# 499994  1008.0              Gannawarra             46093
# 499995  1580.0    Uraidla - Summertown             71963
# 499996  1221.0               Jondaryan             50927
# 499997  1869.0           Perth Airport             74118
# 499998   228.0  Hamilton - Broadmeadow             70533
#
# [499999 rows x 11 columns]

# %%
df.to_csv('../data/curated/consumer_income.csv')

# %%
income_df1.to_csv('../data/curated/income.csv')
