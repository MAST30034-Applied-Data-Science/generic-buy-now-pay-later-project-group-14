# %% [markdown]
# # Consumer's dataset merging process

# %%
import folium
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
consumer = pd.read_parquet("../data/curated/consumer/")
processed_postcode = pd.read_csv('../data/curated/processed_postcode.csv')
processed_postcode = processed_postcode[['postcode', 'SA2_code']]
processed_postcode
# Out:
#       postcode     SA2_code
# 0          200  801051049.0
# 1          800  701011002.0
# 2          801  701011002.0
# 3          804  701011007.0
# 4          810  701021010.0
# ...        ...          ...
# 3162      9013  305011105.0
# 3163      9015  305011105.0
# 3164      9464  302031038.0
# 3165      9726  309101268.0
# 3166      9999  206041122.0
#
# [3167 rows x 2 columns]

# %%
df = pd.read_parquet("../data/curated/consumer/")
df
# Out:
#         consumer_id  user_id state  postcode  gender
# 0                28   458885    WA      6176    Male
# 1                78   319257    SA      5410    Male
# 2               101     9180    SA      5554  Female
# 3               108   191536    SA      5052  Female
# 4               133   234634    WA      6985    Male
# ...             ...      ...   ...       ...     ...
# 499994      1499869   381121   QLD      4403  Female
# 499995      1499885   325002   TAS      7163    Male
# 499996      1499910   414057   NSW      2090  Female
# 499997      1499911    56561    WA      6105  Female
# 499998      1499917   360988   NSW      2292    Male
#
# [499999 rows x 5 columns]

# %%
income_df = pd.read_excel('../data/external/total_income.xlsx', sheet_name='Table 1.4')
income_df
# Out:
#                         Australian Bureau of Statistics  \
# 0     Personal Income in Australia Table 1. Total In...
# 1       Released at 11:30 am (Canberra time) 22/01/2021
# 2                                             Table 1.4
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2301                                          801111140
# 2302                                          801111141
# 2303                                                NaN
# 2304  Totals may not align with the sum of their com...
# 2305  np - not published to protect the confidential...
#
#                                              Unnamed: 1         Unnamed: 2  \
# 0                                                   NaN                NaN
# 1                                                   NaN                NaN
# 2     Total Income by Statistical Area Level 2 (2014...                NaN
# 3                                                   NaN                NaN
# 4                                                   NaN  Earners (persons)
# ...                                                 ...                ...
# 2301                                   ACT - South West                349
# 2302                                            Namadgi                 np
# 2303                                                NaN                NaN
# 2304                                                NaN                NaN
# 2305                                                NaN                NaN
#
#      Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0           NaN        NaN        NaN        NaN
# 1           NaN        NaN        NaN        NaN
# 2           NaN        NaN        NaN        NaN
# 3           NaN        NaN        NaN        NaN
# 4           NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...
# 2301        289        347        364        355
# 2302         np         21         19         18
# 2303        NaN        NaN        NaN        NaN
# 2304        NaN        NaN        NaN        NaN
# 2305        NaN        NaN        NaN        NaN
#
#                          Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 18  \
# 0                               NaN        NaN        NaN  ...         NaN
# 1                               NaN        NaN        NaN  ...         NaN
# 2                               NaN        NaN        NaN  ...         NaN
# 3                               NaN        NaN        NaN  ...         NaN
# 4     Median age of earners (years)        NaN        NaN  ...         NaN
# ...                             ...        ...        ...  ...         ...
# 2301                             40         39         39  ...       62592
# 2302                             np         np         34  ...          np
# 2303                            NaN        NaN        NaN  ...         NaN
# 2304                            NaN        NaN        NaN  ...         NaN
# 2305                            NaN        NaN        NaN  ...         NaN
#
#      Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN    Mean ($)         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 2301       55384       61096       64227       62505       72858       70503
# 2302       49981       58498       40479          np          np       57309
# 2303         NaN         NaN         NaN         NaN         NaN         NaN
# 2304         NaN         NaN         NaN         NaN         NaN         NaN
# 2305         NaN         NaN         NaN         NaN         NaN         NaN
#
#      Unnamed: 25 Unnamed: 26 Unnamed: 27
# 0            NaN         NaN         NaN
# 1            NaN         NaN         NaN
# 2            NaN         NaN         NaN
# 3            NaN         NaN         NaN
# 4            NaN         NaN         NaN
# ...          ...         ...         ...
# 2301       67445       73435         NaN
# 2302       56357       39278         NaN
# 2303         NaN         NaN         NaN
# 2304         NaN         NaN         NaN
# 2305         NaN         NaN         NaN
#
# [2306 rows x 28 columns]

# %%
income_df1 = income_df.drop(income_df.index[0:6], inplace=False).reset_index(drop=True)
income_df1.columns = income_df.iloc[5].values.flatten().tolist()
income_df1 = (income_df1.iloc[:, [0, 1, 26]])
income_df1.drop(income_df1.index[2297:2300], inplace=True)
income_df1.rename(columns={'2018-19':'Mean_Total_Income'}, inplace=True)
income_df1.rename(columns={'SA2':'SA2_code'}, inplace=True)
income_df1 = income_df1.dropna().reset_index(drop = True)
#income_df1.astype({'SA2': 'int'})
#income_df1.to_csv("../data/curated/income.csv")

# %%
income_df1['Mean_Total_Income'] = income_df1['Mean_Total_Income'].replace('np', np.NAN)

# %%
type(income_df1["Mean_Total_Income"].iloc[0])
# Out:
# numpy.float64

# %%
SA2_missing = income_df1[(income_df1.isnull()).any(axis=1)]
SA2_missing.shape
# Out:
# (44, 3)

# %%
# Dataset has multiple areas with postcode 2611, check the existance the one in ACT
df.loc[(df['postcode']==2611) & (df['state'] == 'ACT')]
# Out:
# Empty DataFrame
# Columns: [consumer_id, user_id, state, postcode, gender]
# Index: []

# %%
df = consumer.merge(processed_postcode, on='postcode', how='left')
df.isna().values.any()
# Out:
# True

# %%
df[df['user_id'] == 18666]
# Out:
#         consumer_id  user_id state  postcode gender  SA2_code
# 157529      1420365    18666   VIC      3989   Male       NaN

# %%
income_df1
# Out:
#        SA2_code           SA2 NAME  Mean_Total_Income
# 0     101021007          Braidwood            51149.0
# 1     101021008            Karabar            66335.0
# 2     101021009         Queanbeyan            65874.0
# 3     101021010  Queanbeyan - East            69860.0
# 4     101021011  Queanbeyan Region            81919.0
# ...         ...                ...                ...
# 2283  801101137           Molonglo                NaN
# 2284  801101138   Molonglo - North                NaN
# 2285  801101139             Wright            86007.0
# 2286  801111140   ACT - South West            73435.0
# 2287  801111141            Namadgi            39278.0
#
# [2288 rows x 3 columns]

# %%
# combining consumer with mean total income based on SA2 code
df = df.merge(income_df1, on='SA2_code', how='left')

# %%
df[df['user_id'] == 18666]
# Out:
#         consumer_id  user_id state  postcode gender SA2_code SA2 NAME  \
# 157529      1420365    18666   VIC      3989   Male      NaN      NaN
#
#         Mean_Total_Income
# 157529                NaN

# %% [markdown]
# ### Missing values

# %% [markdown]
# #### find mean income per state to replace missing value in 'mean total income'

# %%
state_income = income_df.drop(income_df.index[0:6], inplace=False).reset_index(drop=True)
state_income
# Out:
#                         Australian Bureau of Statistics        Unnamed: 1  \
# 0                                            Australia                NaN
# 1                                       New South Wales               NaN
# 2                                             101021007         Braidwood
# 3                                             101021008           Karabar
# 4                                             101021009        Queanbeyan
# ...                                                 ...               ...
# 2295                                          801111140  ACT - South West
# 2296                                          801111141           Namadgi
# 2297                                                NaN               NaN
# 2298  Totals may not align with the sum of their com...               NaN
# 2299  np - not published to protect the confidential...               NaN
#
#      Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0      13102895   13358252   13678024   14069082   14425037         42
# 1       4091347    4191542    4344997    4466941    4569650         42
# 2          2133       2153       2262       2315       2361         50
# 3          4866       4937       4988       5059       5100         43
# 4          6194       6419       6486       6595       6697         40
# ...         ...        ...        ...        ...        ...        ...
# 2295        349        289        347        364        355         40
# 2296         np         np         21         19         18         np
# 2297        NaN        NaN        NaN        NaN        NaN        NaN
# 2298        NaN        NaN        NaN        NaN        NaN        NaN
# 2299        NaN        NaN        NaN        NaN        NaN        NaN
#
#      Unnamed: 8 Unnamed: 9  ... Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0            42         42  ...       47692       48360       49805
# 1            42         42  ...       48085       48700       50153
# 2            50         50  ...       39716       41288       42003
# 3            42         42  ...       55870       57880       59295
# 4            39         39  ...       54999       55376       57848
# ...         ...        ...  ...         ...         ...         ...
# 2295         39         39  ...       62592       55384       61096
# 2296         np         34  ...          np       49981       58498
# 2297        NaN        NaN  ...         NaN         NaN         NaN
# 2298        NaN        NaN  ...         NaN         NaN         NaN
# 2299        NaN        NaN  ...         NaN         NaN         NaN
#
#      Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# 0          51389       61036       61975       62594       64246       65953
# 1          51818       62798       64493       65196       67200       68816
# 2          41593       47741       51074       51090       51594       51149
# 3          61777       59548       61093       62535       63790       66335
# 4          60119       59310       60764       60958       62863       65874
# ...          ...         ...         ...         ...         ...         ...
# 2295       64227       62505       72858       70503       67445       73435
# 2296       40479          np          np       57309       56357       39278
# 2297         NaN         NaN         NaN         NaN         NaN         NaN
# 2298         NaN         NaN         NaN         NaN         NaN         NaN
# 2299         NaN         NaN         NaN         NaN         NaN         NaN
#
#      Unnamed: 27
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 2295         NaN
# 2296         NaN
# 2297         NaN
# 2298         NaN
# 2299         NaN
#
# [2300 rows x 28 columns]

# %%
states = ['New South Wales', 'Victoria', 'Queensland', 'South Australia', 'Western Australia', 'Tasmania', 'Northern Territory', 'Australian Capital Territory']
state_income = state_income[state_income.iloc[:, 0].isin(states)].iloc[:, [0, 26]]

# %%
abbrv = ['NSW', 'VIC','QLD', 'SA', 'WA', 'TAS', 'NT', 'ACT']
state_income.iloc[:,0] = state_income.iloc[:,0].replace(states,abbrv)
state_income.rename(columns={'Unnamed: 26':'Mean_Total_Income'}, inplace=True)
state_income = state_income.set_index(state_income.iloc[:, 0])
state_income = state_income.to_dict()['Mean_Total_Income']

# %%
state_income['NSW']
# Out:
# 68816

# %%
for state in abbrv:
  df.loc[(df['state'] == state)&(df['Mean_Total_Income'].isna()), ['SA2 NAME','Mean_Total_Income']] = [state, state_income[state]]

# %%
df[df['user_id'] == 18662]
# Out:
#         consumer_id  user_id state  postcode  gender     SA2_code SA2 NAME  \
# 496379      1411657    18662    SA      5110  Female  402041039.0       SA
#
#         Mean_Total_Income
# 496379            59875.0

# %%
df.dtypes
# Out:
# consumer_id            int32
# user_id                int32
# state                 object
# postcode               int32
# gender                object
# SA2_code              object
# SA2 NAME              object
# Mean_Total_Income    float64
# dtype: object

# %%
df
# Out:
#         consumer_id  user_id state  postcode  gender     SA2_code  \
# 0                28   458885    WA      6176    Male  507051185.0
# 1                78   319257    SA      5410    Male  405011111.0
# 2               101     9180    SA      5554  Female  405041125.0
# 3               108   191536    SA      5052  Female  403031065.0
# 4               133   234634    WA      6985    Male  506021122.0
# ...             ...      ...   ...       ...     ...          ...
# 499994      1499869   381121   QLD      4403  Female  307021179.0
# 499995      1499885   325002   TAS      7163    Male  603021069.0
# 499996      1499910   414057   NSW      2090  Female  121041413.0
# 499997      1499911    56561    WA      6105  Female  506021122.0
# 499998      1499917   360988   NSW      2292    Male  111031224.0
#
#                                 SA2 NAME  Mean_Total_Income
# 0                               Baldivis            70678.0
# 1                                  Light            55650.0
# 2                                 Moonta            46898.0
# 3                                 Belair            73814.0
# 4       Rivervale - Kewdale - Cloverdale            61942.0
# ...                                  ...                ...
# 499994              Crows Nest - Rosalie            44615.0
# 499995          Bruny Island - Kettering            53377.0
# 499996               Cremorne - Cammeray           123563.0
# 499997  Rivervale - Kewdale - Cloverdale            61942.0
# 499998            Hamilton - Broadmeadow            70533.0
#
# [499999 rows x 8 columns]

# %% [markdown]
# ### drop rows with missing SA2_code

# %%
#df = df.dropna()

# %%
#df
# Out:
#         consumer_id  user_id state  postcode  gender     SA2_code  \
# 0                28   458885    WA      6176    Male  507051185.0
# 1                78   319257    SA      5410    Male  405011111.0
# 2               101     9180    SA      5554  Female  405041125.0
# 3               108   191536    SA      5052  Female  403031065.0
# 4               133   234634    WA      6985    Male  506021122.0
# ...             ...      ...   ...       ...     ...          ...
# 499994      1499869   381121   QLD      4403  Female  307021179.0
# 499995      1499885   325002   TAS      7163    Male  603021069.0
# 499996      1499910   414057   NSW      2090  Female  121041413.0
# 499997      1499911    56561    WA      6105  Female  506021122.0
# 499998      1499917   360988   NSW      2292    Male  111031224.0
#
#                                 SA2 NAME  Mean_Total_Income
# 0                               Baldivis            70678.0
# 1                                  Light            55650.0
# 2                                 Moonta            46898.0
# 3                                 Belair            73814.0
# 4       Rivervale - Kewdale - Cloverdale            61942.0
# ...                                  ...                ...
# 499994              Crows Nest - Rosalie            44615.0
# 499995          Bruny Island - Kettering            53377.0
# 499996               Cremorne - Cammeray           123563.0
# 499997  Rivervale - Kewdale - Cloverdale            61942.0
# 499998            Hamilton - Broadmeadow            70533.0
#
# [498456 rows x 8 columns]

# %%
df[df['user_id'] == 18662]
# Out:
#         consumer_id  user_id state  postcode  gender     SA2_code SA2 NAME  \
# 496379      1411657    18662    SA      5110  Female  402041039.0       SA
#
#         Mean_Total_Income
# 496379            59875.0

# %%
df.to_csv('../data/curated/clean_consumer_post_total_income.csv')

# %% [markdown]
# ## Model Features selection
#
# Transaction dollar * take rate = BNPL revenue
#
# Level a-e ?
#
# Transaction Volumn
#
# Average transaction amount per merchant
#
# Growth rate per merchant (Transaction Volumn + amount)
#
# Number of consumers (more -> Riskless?)
#
# Brand loyalty

# %% [markdown]
# ### Revenue prediction
# y = next year revenue
# x = past data
#
# new merchants are not considered
