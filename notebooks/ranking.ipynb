# %%
import pandas as pd
from functools import reduce

# %%
# read data
num_consumer = pd.read_csv('../data/curated/pred_total_num_consumer.csv')
num_transaction = pd.read_csv('../data/curated/pred_total_num_transaction.csv')
revenue = pd.read_csv('../data/curated/pred_total_revenue.csv')
merchant_info = pd.read_csv('../data/curated/merchant.csv')

# merge three data frames based on merchant abn
data_frames = [merchant_info, num_consumer, num_transaction, revenue]
df_merged = reduce(lambda left,right: pd.merge(left,right,on=['merchant_abn'], how='outer'), data_frames)
df_merged
# Out:
#       merchant_abn                                  name       tags  \
# 0      10023283211                         Felis Limited  furniture
# 1      10142254217              Arcu Ac Orci Corporation      cable
# 2      10165489824                      Nunc Sed Company    jewelry
# 3      10187291046  Ultricies Dignissim Lacus Foundation      watch
# 4      10192359162                   Enim Condimentum PC      music
# ...            ...                                   ...        ...
# 4021   99938978285                    Elit Dictum Eu Ltd  opticians
# 4022   99974311662                            Mollis LLP      books
# 4023   99976658299                        Sociosqu Corp.       shoe
# 4024   99987905597                 Commodo Hendrerit LLC      motor
# 4025   99990536339                              Massa PC      motor
#
#      revenue_level  take_rate  y_pred_total_num_consumer  \
# 0                e       0.18                2130.976342
# 1                b       4.22                1904.673169
# 2                b       4.40                        NaN
# 3                b       3.29                 232.572609
# 4                a       6.33                 242.355650
# ...            ...        ...                        ...
# 4021             b       4.50                9311.509743
# 4022             b       3.17                  97.286540
# 4023             a       6.57               11449.076286
# 4024             a       6.82                 101.807210
# 4025             e       0.18                  13.816558
#
#       y_pred_total_num_transaction  y_pred_total_revenue
# 0                      2215.326353          6.306584e+05
# 1                      1983.119759          3.104424e+05
# 2                              NaN                   NaN
# 3                       231.071404          8.055615e+04
# 4                       239.045462          6.899121e+05
# ...                            ...                   ...
# 4021                  11823.555676          1.513780e+06
# 4022                    101.514524          9.482091e+04
# 4023                  15846.420171          1.621151e+07
# 4024                    106.359865          1.947298e+05
# 4025                     20.572534          5.591319e+03
#
# [4026 rows x 8 columns]

# %%
# impute missing values and negative values with zero
df_merged = df_merged.fillna(0)
num = df_merged._get_numeric_data()
num[num < 0] = 0
df_merged
# Out:
#       merchant_abn                                  name       tags  \
# 0      10023283211                         Felis Limited  furniture
# 1      10142254217              Arcu Ac Orci Corporation      cable
# 2      10165489824                      Nunc Sed Company    jewelry
# 3      10187291046  Ultricies Dignissim Lacus Foundation      watch
# 4      10192359162                   Enim Condimentum PC      music
# ...            ...                                   ...        ...
# 4021   99938978285                    Elit Dictum Eu Ltd  opticians
# 4022   99974311662                            Mollis LLP      books
# 4023   99976658299                        Sociosqu Corp.       shoe
# 4024   99987905597                 Commodo Hendrerit LLC      motor
# 4025   99990536339                              Massa PC      motor
#
#      revenue_level  take_rate  y_pred_total_num_consumer  \
# 0                e       0.18                2130.976342
# 1                b       4.22                1904.673169
# 2                b       4.40                   0.000000
# 3                b       3.29                 232.572609
# 4                a       6.33                 242.355650
# ...            ...        ...                        ...
# 4021             b       4.50                9311.509743
# 4022             b       3.17                  97.286540
# 4023             a       6.57               11449.076286
# 4024             a       6.82                 101.807210
# 4025             e       0.18                  13.816558
#
#       y_pred_total_num_transaction  y_pred_total_revenue
# 0                      2215.326353          6.306584e+05
# 1                      1983.119759          3.104424e+05
# 2                         0.000000          0.000000e+00
# 3                       231.071404          8.055615e+04
# 4                       239.045462          6.899121e+05
# ...                            ...                   ...
# 4021                  11823.555676          1.513780e+06
# 4022                    101.514524          9.482091e+04
# 4023                  15846.420171          1.621151e+07
# 4024                    106.359865          1.947298e+05
# 4025                     20.572534          5.591319e+03
#
# [4026 rows x 8 columns]

# %% [markdown]
# ### Ranking System
# The ranking system utilises predicted "total number of consumers", "total number of transactions" and "total revenue" next year and give each merchant a score within 0-100. The ranking score is calculated as follows:
#
# 1. Standardise each attribute using min-max normalization
# 2. Total number of consumers * 30%
# 3. BNPL revenue * 40%
# 4. Total number of transactions * 30%
#
# Revenue accounts for a larger proportion because it is considered to be an important thing to the BNPL company.

# %%
# min-max normalization
features = ['pred_total_num_consumer', 'pred_total_num_transaction', 'pred_total_revenue']
for col in features:
    df_merged[f'scaled_{col}'] = 100 * (df_merged[col] - df_merged[col].min()) / (df_merged[col].max() - df_merged[col].min())    

df_merged.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pred_total_num_consumer'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /home/stluo/ADS tut/generic-buy-now-pay-later-project-group-14/notebooks/ranking.ipynb Cell 5 in <cell line: 3>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/stluo/ADS%20tut/generic-buy-now-pay-later-project-group-14/notebooks/ranking.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> features = ['pred_total_num_consumer', 'pred_total_num_transaction', 'pred_total_revenue']
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/stluo/ADS%20tut/generic-buy-now-pay-later-project-group-14/notebooks/ranking.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> for col in features:
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/stluo/ADS%20tut/generic-buy-now-pay-later-project-group-14/notebooks/ranking.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     df_merged[f'scaled_{col}'] = 100 * (df_merged[col] - df_merged[col].min()) / (df_merged[col].max() - df_merged[col].min())
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/stluo/ADS%20tut/generic-buy-now-pay-later-project-group-14/notebooks/ranking.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> df_merged.head()
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'pred_total_num_consumer'

# %%
# calculate ranking score for each merchant
df_merged['score'] = 0.3*df_merged['scaled_pred_total_num_consumer'] + 0.3*df_merged['scaled_pred_total_num_transaction'] + 0.4*df_merged['scaled_pred_total_revenue']

df_merged['rank'] = df_merged['score'].rank(ascending=False)
df_merged = df_merged.set_index('rank').sort_index()
df_merged.head()
# Out:
#       merchant_abn                       name   tags revenue_level  take_rate  \
# rank
# 1.0    86578477987          Leo In Consulting  watch             a       6.43
# 2.0    45629217853           Lacus Consulting   gift             a       6.98
# 3.0    89726005175        Est Nunc Consulting   tent             a       6.01
# 4.0    49891706470  Non Vestibulum Industries   tent             a       5.80
# 5.0    21439773999       Mauris Non Institute  cable             a       6.10
#
#       pred_total_num_consumer  pred_total_num_transaction  pred_total_revenue  \
# rank
# 1.0              18424.119848               187019.058114        4.294892e+07
# 2.0              20247.863835               152088.705358        4.134455e+07
# 3.0              20487.094245               148292.570591        3.710350e+07
# 4.0              19617.385531               169851.702773        2.916461e+07
# 5.0              22427.261712                81994.383461        3.671589e+07
#
#       scaled_pred_total_num_consumer  scaled_pred_total_num_transaction  \
# rank
# 1.0                        82.008301                          93.866355
# 2.0                        90.126037                          76.334533
# 3.0                        91.190884                          74.429222
# 4.0                        87.319691                          85.249922
# 5.0                        99.826838                          41.153634
#
#       scaled_pred_total_revenue      score
# rank
# 1.0                  100.000000  92.762397
# 2.0                   96.264467  88.443957
# 3.0                   86.389832  84.241965
# 4.0                   67.905351  78.933024
# 5.0                   85.487345  76.489080

# %% [markdown]
# ### Split Merchants into 4 Segments
# Based on [Merchant Cateogry Groups by ANZ](https://www.anz.com/Documents/Business/CommercialCard/Merchant_cateogry_codes_control.pdf), we devide all merchant into 4 categories.
#
# 1. Health service: health, optician
#
# 2. Recreational good retailing: bicycle, books, stationary, hobby, tent, digital goods,
#
# 3. Personal & household good retail: antique, watch, jewellery, music, artist supply, gift, art dealer, florists, furniture, shoe, garden supply,
#
# 4. Technical & machinery service: cable, telecom, computer, equipment, motor

# %%
# split merchants into 4 segments
segment = {
    'furniture': 'personal & household good retail',
    'cable': 'technical & machinery service',
    'watch': 'personal & household good retail',
    'music': 'personal & household good retail',
    'gift': 'personal & household good retail',
    'computer': 'technical & machinery service',
    'equipment': 'technical & machinery service',
    'artist supply': 'personal & household good retail',
    'florists': 'personal & household good retail',
    'motor': 'technical & machinery service',
    'books': 'recreational good retailing',
    'jewelry': 'personal & household good retail',
    'stationery': 'recreational good retailing',
    'tent': 'recreational good retailing',
    'art dealer': 'personal & household good retail',
    'bicycle': 'recreational good retailing',
    'digital goods': 'recreational good retailing',
    'shoe': 'personal & household good retail',
    'opticians': 'health service',
    'antique': 'personal & household good retail',
    'health': 'health service',
    'hobby': 'recreational good retailing',
    'garden supply': 'personal & household good retail',
    'telecom': 'technical & machinery service'
}

df_merged['segment'] = df_merged['tags'].map(segment)

# %%
# find top 100 merchants overall
top100 = df_merged.loc[df_merged.index <= 100]
top100.to_csv('../data/curated/top100.csv')

# %%
# find top 10 merchants in each segment
df_merged.loc[df_merged['segment']=='personal & household good retail'].head(10)
# Out:
#       merchant_abn                               name           tags  \
# rank
# 1.0    86578477987                  Leo In Consulting          watch
# 2.0    45629217853                   Lacus Consulting           gift
# 6.0    64403598239          Lobortis Ultrices Company          music
# 7.0    43186523025     Lorem Ipsum Sodales Industries       florists
# 8.0    24852446429                     Erat Vitae LLP       florists
# 9.0    32361057556      Orci In Consequat Corporation           gift
# 10.0   94493496784      Dictum Phasellus In Institute           gift
# 13.0   79417999332               Phasellus At Company           gift
# 14.0   63290521567  Vehicula Pellentesque Corporation  artist supply
# 17.0   60956456424            Ultricies Dignissim LLP           gift
#
#      revenue_level  take_rate  pred_total_num_consumer  \
# rank
# 1.0              a       6.43             18424.119848
# 2.0              a       6.98             20247.863835
# 6.0              a       6.31             22466.164669
# 7.0              b       4.47             21202.341117
# 8.0              c       2.94             18397.050800
# 9.0              a       6.61             21585.405795
# 10.0             a       5.65             22246.385803
# 13.0             b       4.95             22391.675691
# 14.0             a       6.48             22137.241349
# 17.0             b       4.69             22142.323584
#
#       pred_total_num_transaction  pred_total_revenue  \
# rank
# 1.0                187019.058114        4.294892e+07
# 2.0                152088.705358        4.134455e+07
# 6.0                 77955.860970        3.649622e+07
# 7.0                138223.041477        2.820588e+07
# 8.0                199239.715252        1.846790e+07
# 9.0                 58492.624820        3.586128e+07
# 10.0                67378.171226        3.237761e+07
# 13.0                67990.538900        2.920388e+07
# 14.0               119974.735676        2.002043e+07
# 17.0                62221.579534        2.609762e+07
#
#       scaled_pred_total_num_consumer  scaled_pred_total_num_transaction  \
# rank
# 1.0                        82.008301                          93.866355
# 2.0                        90.126037                          76.334533
# 6.0                       100.000000                          39.126668
# 7.0                        94.374547                          69.375245
# 8.0                        81.887812                         100.000000
# 9.0                        96.079621                          29.357914
# 10.0                       99.021734                          33.817641
# 13.0                       99.668439                          34.124993
# 14.0                       98.535917                          60.216275
# 17.0                       98.558539                          31.229506
#
#       scaled_pred_total_revenue      score                           segment
# rank
# 1.0                  100.000000  92.762397  personal & household good retail
# 2.0                   96.264467  88.443957  personal & household good retail
# 6.0                   84.975878  75.728351  personal & household good retail
# 7.0                   65.673087  75.394173  personal & household good retail
# 8.0                   42.999696  71.766222  personal & household good retail
# 9.0                   83.497511  71.030265  personal & household good retail
# 10.0                  75.386324  70.006342  personal & household good retail
# 13.0                  67.996787  67.336744  personal & household good retail
# 14.0                  46.614523  66.271467  personal & household good retail
# 17.0                  60.764330  63.242146  personal & household good retail

# %%
df_merged.loc[df_merged['segment']=='technical & machinery service'].head(10)
# Out:
#       merchant_abn                               name      tags revenue_level  \
# rank
# 5.0    21439773999               Mauris Non Institute     cable             a
# 18.0   68216911708    Placerat Eget Venenatis Limited  computer             c
# 23.0   96680767841                     Ornare Limited     motor             a
# 24.0   35909341340           Arcu Sed Eu Incorporated  computer             b
# 29.0   67400260923                        Eleifend PC  computer             a
# 31.0   94690988633                    Eu Placerat LLC  computer             a
# 35.0   58454491168                 Diam At Foundation  computer             a
# 39.0   80518954462      Neque Sed Dictum Incorporated  computer             b
# 49.0   17488304283  Posuere Cubilia Curae Corporation     cable             a
# 50.0   13514558491                  Magna Praesent PC     motor             a
#
#       take_rate  pred_total_num_consumer  pred_total_num_transaction  \
# rank
# 5.0        6.10             22427.261712                81994.383461
# 18.0       3.05             22179.480322               123795.665204
# 23.0       5.91             13358.259421                20437.638529
# 24.0       4.80             15347.860798                25516.439230
# 29.0       5.97             15703.501465                25799.417587
# 31.0       6.16             13895.359162                21106.140391
# 35.0       6.01             12295.206852                17815.299684
# 39.0       3.49             13433.743004                19968.557971
# 49.0       6.18             14833.881547                23201.967296
# 50.0       6.78              9261.062218                12024.158499
#
#       pred_total_revenue  scaled_pred_total_num_consumer  \
# rank
# 5.0         3.671589e+07                       99.826838
# 18.0        1.482190e+07                       98.723928
# 23.0        3.280536e+07                       59.459457
# 24.0        2.701189e+07                       68.315447
# 29.0        2.366131e+07                       69.898453
# 31.0        2.506659e+07                       61.850162
# 35.0        2.553472e+07                       54.727663
# 39.0        2.005035e+07                       59.795444
# 49.0        1.405879e+07                       66.027654
# 50.0        2.373192e+07                       41.222266
#
#       scaled_pred_total_num_transaction  scaled_pred_total_revenue      score  \
# rank
# 5.0                           41.153634                  85.487345  76.489080
# 18.0                          62.134030                  34.510520  62.061596
# 23.0                          10.257814                  76.382273  51.468090
# 24.0                          12.806904                  62.893064  49.493931
# 29.0                          12.948933                  55.091745  46.890914
# 31.0                          10.593340                  58.363738  45.078546
# 35.0                           8.941641                  59.453696  42.882269
# 39.0                          10.022378                  46.684179  39.619018
# 49.0                          11.645252                  32.733757  36.395375
# 50.0                           6.035021                  55.256144  36.279644
#
#                             segment
# rank
# 5.0   technical & machinery service
# 18.0  technical & machinery service
# 23.0  technical & machinery service
# 24.0  technical & machinery service
# 29.0  technical & machinery service
# 31.0  technical & machinery service
# 35.0  technical & machinery service
# 39.0  technical & machinery service
# 49.0  technical & machinery service
# 50.0  technical & machinery service

# %%
df_merged.loc[df_merged['segment']=='recreational good retailing'].head(10)
# Out:
#       merchant_abn                          name           tags revenue_level  \
# rank
# 3.0    89726005175           Est Nunc Consulting           tent             a
# 4.0    49891706470     Non Vestibulum Industries           tent             a
# 11.0   72472909171             Nullam Consulting  digital goods             a
# 12.0   64203420245            Pede Nonummy Corp.           tent             c
# 20.0   98973094975             Ornare Fusce Inc.          hobby             a
# 22.0   49505931725     Suspendisse Ac Associates  digital goods             b
# 26.0   35223308778              Euismod In Corp.          books             b
# 37.0   57900494384  Porttitor Tellus Corporation           tent             a
# 38.0   91923722701        Euismod Urna Institute           tent             b
# 41.0   96152467973      Rhoncus Donec Associates           tent             b
#
#       take_rate  pred_total_num_consumer  pred_total_num_transaction  \
# rank
# 3.0        6.01             20487.094245               148292.570591
# 4.0        5.80             19617.385531               169851.702773
# 11.0       6.33             22452.125399                69864.891981
# 12.0       2.86             19445.345139               179730.272883
# 20.0       5.98             18805.618554                37234.745984
# 22.0       4.70             20700.055683                46964.302731
# 26.0       4.19             17267.513531                30539.425023
# 37.0       6.39             20777.940056                45433.031962
# 38.0       5.05             21554.269116                50434.799116
# 41.0       4.45             20950.436589                46434.965454
#
#       pred_total_revenue  scaled_pred_total_num_consumer  \
# rank
# 3.0         3.710350e+07                       91.190884
# 4.0         2.916461e+07                       87.319691
# 11.0        3.076982e+07                       99.937509
# 12.0        1.597363e+07                       86.553915
# 20.0        2.801662e+07                       83.706404
# 22.0        2.317002e+07                       92.138805
# 26.0        2.210223e+07                       76.860086
# 37.0        5.896677e+06                       92.485479
# 38.0        3.935804e+06                       95.941027
# 41.0        4.368107e+06                       93.253285
#
#       scaled_pred_total_num_transaction  scaled_pred_total_revenue      score  \
# rank
# 3.0                           74.429222                  86.389832  84.241965
# 4.0                           85.249922                  67.905351  78.933024
# 11.0                          35.065746                  71.642824  69.158106
# 12.0                          90.208055                  37.192157  67.905454
# 20.0                          18.688416                  65.232419  56.811413
# 22.0                          23.571758                  53.947846  56.292307
# 26.0                          15.327981                  51.461669  48.241088
# 37.0                          22.803201                  13.729512  40.078409
# 38.0                          25.313627                   9.163919  40.041964
# 41.0                          23.306079                  10.170469  39.035997
#
#                           segment
# rank
# 3.0   recreational good retailing
# 4.0   recreational good retailing
# 11.0  recreational good retailing
# 12.0  recreational good retailing
# 20.0  recreational good retailing
# 22.0  recreational good retailing
# 26.0  recreational good retailing
# 37.0  recreational good retailing
# 38.0  recreational good retailing
# 41.0  recreational good retailing

# %%
df_merged.loc[df_merged['segment']=='health service'].head(10)
# Out:
#        merchant_abn                               name       tags  \
# rank
# 15.0    48534649627      Dignissim Maecenas Foundation  opticians
# 16.0    46804135891        Suspendisse Dui Corporation  opticians
# 76.0    11566786699               Euismod Et Institute  opticians
# 81.0    41251795489              Ultricies Sem Limited  opticians
# 92.0    18158387243                     Nec Tellus Ltd     health
# 99.0    95574756848                       At Pede Inc.  opticians
# 101.0   22059270846  Montes Nascetur Ridiculus Limited  opticians
# 102.0   88699453206                       Sed Nec Inc.     health
# 113.0   11237511112                    Magna Institute  opticians
# 118.0   81410315303                      Sed Dictum PC  opticians
#
#       revenue_level  take_rate  pred_total_num_consumer  \
# rank
# 15.0              a       6.64             19815.016496
# 16.0              c       2.93             20658.123723
# 76.0              c       2.62             17236.981577
# 81.0              c       2.91             16477.506055
# 92.0              c       2.03              8614.577745
# 99.0              a       6.15              6440.832791
# 101.0             a       6.59             13327.032188
# 102.0             b       3.53              6784.287852
# 113.0             c       2.11             10727.462619
# 118.0             a       6.35             11610.838917
#
#        pred_total_num_transaction  pred_total_revenue  \
# rank
# 15.0                 43727.399132        3.548214e+07
# 16.0                156457.125445        1.494323e+07
# 76.0                 29767.087733        2.279885e+06
# 81.0                 27195.162539        2.258437e+06
# 92.0                 10809.436463        1.345239e+07
# 99.0                  7590.715190        1.558179e+07
# 101.0                19118.854624        3.533241e+06
# 102.0                 8104.475549        1.455521e+07
# 113.0                14281.054137        6.214697e+06
# 118.0                15971.040165        4.277344e+06
#
#        scaled_pred_total_num_consumer  scaled_pred_total_num_transaction  \
# rank
# 15.0                        88.199374                          21.947130
# 16.0                        91.952160                          78.527077
# 76.0                        76.724184                          14.940338
# 81.0                        73.343654                          13.649469
# 92.0                        38.344675                           5.425342
# 99.0                        28.669036                           3.809840
# 101.0                       59.320460                           9.595905
# 102.0                       30.197802                           4.067701
# 113.0                       47.749417                           7.167775
# 118.0                       51.681447                           8.015992
#
#        scaled_pred_total_revenue      score         segment
# rank
# 15.0                   82.614752  66.089852  health service
# 16.0                   34.793033  65.060984  health service
# 76.0                    5.308365  29.622703  health service
# 81.0                    5.258426  28.201307  health service
# 92.0                   31.321827  25.659736  health service
# 99.0                   36.279811  24.255587  health service
# 101.0                   8.226612  23.965554  health service
# 102.0                  33.889586  23.835485  health service
# 113.0                  14.469974  22.263147  health service
# 118.0                   9.959142  21.892888  health service
